# %% [markdown]
# <a href="https://colab.research.google.com/github/umedadada/nikkei_software_202407/blob/master/2024_nikkei_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ライブラリの読み込み
import pandas as pd #データを取り扱うためのライブラリ
import plotly.express as px #データを可視化するためのライブラリ

# %%
# データの読み込み
raw_df=pd.read_csv('./FEH_00200521_240311192951.csv',encoding="shift-jis")
# データのカラム確認
raw_df.info()
# データの表示
raw_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tab_code    4200 non-null   int64
#  1   表章項目        4200 non-null   object
#  2   cat01_code  4200 non-null   int64
#  3   男女_時系列      4200 non-null   object
#  4   area_code   4200 non-null   int64
#  5   地域_時系列      4200 non-null   object
#  6   time_code   4200 non-null   int64
#  7   時間軸（調査年）    4200 non-null   object
#  8   unit        3150 non-null   object
#  9   value       4200 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 328.2+ KB
#       tab_code  表章項目  cat01_code 男女_時系列  area_code 地域_時系列   time_code  \
# 0           20    人口         100     総数          0     全国  1920000000
# 1           20    人口         100     総数          0     全国  1925000000
# 2           20    人口         100     総数          0     全国  1930000000
# 3           20    人口         100     総数          0     全国  1935000000
# 4           20    人口         100     総数          0     全国  1940000000
# ...        ...   ...         ...    ...        ...    ...         ...
# 4195      1120  人口性比         100     総数      47000    沖縄県  2000000000
# 4196      1120  人口性比         100     総数      47000    沖縄県  2005000000
# 4197      1120  人口性比         100     総数      47000    沖縄県  2010000000
# 4198      1120  人口性比         100     総数      47000    沖縄県  2015000000
# 4199      1120  人口性比         100     総数      47000    沖縄県  2020000000
#
#      時間軸（調査年） unit          value
# 0       1920年    人       55963053
# 1       1925年    人       59736822
# 2       1930年    人       64450005
# 3       1935年    人       69254148
# 4       1940年    人       73114308
# ...       ...  ...            ...
# 4195    2000年  NaN  96.6485813978
# 4196    2005年  NaN  96.4521304531
# 4197    2010年  NaN  96.3125625449
# 4198    2015年  NaN  96.6625831508
# 4199    2020年  NaN         97.065
#
# [4200 rows x 10 columns]

# %%
# データの前処理
df = raw_df[(raw_df['表章項目']=='人口') & #指標を人口に絞る
            (raw_df['男女_時系列']=='総数') & #男女の区別をせず、「総数」を抽出する
            (~raw_df['地域_時系列'].isin(['人口集中地区', '人口集中地区以外の地区']))] #全国と各都道府県のデータのみを抽出する
df = df[['時間軸（調査年）','地域_時系列','value']] #カラムを絞る
df.columns = ['year','area','value'] #カラム名を変更する
df = df.assign(value=df['value'].replace('-',0))# 数値以外の値を除去
df = df.assign(value = df['value'].astype('int64')) #数値カラムの型変換をする
df
# Out:
#        year area     value
# 0     1920年   全国  55963053
# 1     1925年   全国  59736822
# 2     1930年   全国  64450005
# 3     1935年   全国  69254148
# 4     1940年   全国  73114308
# ...     ...  ...       ...
# 1045  2000年  沖縄県   1318220
# 1046  2005年  沖縄県   1361594
# 1047  2010年  沖縄県   1392818
# 1048  2015年  沖縄県   1433566
# 1049  2020年  沖縄県   1467480
#
# [1008 rows x 3 columns]

# %%
# 可視化のためのデータ加工
## 条件の絞り込み
viz_df = df[(df['area']!='全国')&
            (df['year']=='2020年')]
## 軸の名前を明示的に指定して可視化
fig=px.bar(viz_df, x='area', y='value')
fig.update_layout(
    title='図. 2020年の各都道府県の人口',
    xaxis=dict(title='都道府県'),
    yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fbc43f34-b5b0-48d4-b7c9-6f9da061df08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb
u770c","\u6ecb\u8cc0\u770c","\u5c71\u53e3\u770c","\u611b\u5a9b\u770c","\u5948\u826f\u770c","\u9577\u5d0e\u770c","\u9752\u68ee\u770c","\u5ca9\u624b\u770c","\u77f3\u5ddd\u770c","\u5927\u5206\u770c","\u5bae\u5d0e\u770c","\u5c71\u5f62\u770c","\u5bcc\u5c71\u770c","\u79cb\u7530\u770c","\u9999\u5ddd\u770c","\u548c\u6b4c\u5c71\u770c","\u4f50\u8cc0\u770c","\u5c71\u68a8\u770c","\u798f\u4e95\u770c","\u5fb3\u5cf6\u770c","\u9ad8\u77e5\u770c","\u5cf6\u6839\u770c","\u9ce5\u53d6\u770c"],"xaxis":"x","y":[14047594,9237337,8837685,7542415,7344765,6284480,5465002,5224614,5135214,3633202,2867009,2799702,2578087,2301996,2201272,2048011,1978742,1939110,1933146,1888432,1833152,1770254,1738301,1588256,1467480,1413610,1342059,1334841,1324473,1312317,1237984,1210534,1132526,1123852,1069576,1068027,1034814,959502,950244,922584,811442,809974,766863,719559,691527,671126,553407],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","co ...

# %%
## 条件の絞り込み
viz_df = df[df['area']=='全国']

## 軸の名前を明示的に指定して可視化
fig=px.bar(viz_df, x='year', y='value')
fig.update_layout(
    title='図. 調査年ごとの人口',
    xaxis=dict(title='調査年'),
    yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="44453d62-1d8e-48fc-ab35-c59f8ef446e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44453d62-1d8e-48fc-ab35-c59f8ef446e1")) {                    Plotly.newPlot(                        "44453d62-1d8e-48fc-ab35-c59f8ef446e1",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[55963053,59736822,64450005,69254148,73114308,71998104,84114574,90076594,94301623,99209137,104665171,111939643,117060396,121048923,123611167,125570246,126925843,127767994,128057352,127094745,126146099],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords"," ...

# %%
# 可視化のためのデータ加工
## 条件の絞り込み
viz_df = df[df['area']=='全国']

## 軸の名前を明示的に指定して可視化
fig=px.line(viz_df, x='year', y='value')
fig.update_layout(
    title='図. 全国人口の推移',
    xaxis=dict(title='調査年'),
    yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5759b1eb-44b4-481e-9133-649a4c5004d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5759b1eb-44b4-481e-9133-649a4c5004d8")) {                    Plotly.newPlot(                        "5759b1eb-44b4-481e-9133-649a4c5004d8",                        [{"hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[55963053,59736822,64450005,69254148,73114308,71998104,84114574,90076594,94301623,99209137,104665171,111939643,117060396,121048923,123611167,125570246,126925843,127767994,128057352,127094745,126146099],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outli ...

# %%
## 条件の絞り込み
check_df = df[df['year']=='1945年']
check_df
# Out:
#        year  area     value
# 5     1945年    全国  71998104
# 68    1945年   北海道   3518389
# 89    1945年   青森県   1083250
# 110   1945年   岩手県   1227789
# 131   1945年   宮城県   1462254
# 152   1945年   秋田県   1211871
# 173   1945年   山形県   1326350
# 194   1945年   福島県   1957356
# 215   1945年   茨城県   1944344
# 236   1945年   栃木県   1546355
# 257   1945年   群馬県   1546081
# 278   1945年   埼玉県   2047261
# 299   1945年   千葉県   1966862
# 320   1945年   東京都   3488284
# 341   1945年  神奈川県   1865667
# 362   1945年   新潟県   2389653
# 383   1945年   富山県    953834
# 404   1945年   石川県    887510
# 425   1945年   福井県    724856
# 446   1945年   山梨県    839057
# 467   1945年   長野県   2121050
# 488   1945年   岐阜県   1518649
# 509   1945年   静岡県   2220358
# 530   1945年   愛知県   2857851
# 551   1945年   三重県   1394286
# 572   1945年   滋賀県    860911
# 593   1945年   京都府   1603796
# 614   1945年   大阪府   2800958
# 635   1945年   兵庫県   2821892
# 656   1945年   奈良県    779685
# 677   1945年  和歌山県    936006
# 698   1945年   鳥取県    563220
# 719   1945年   島根県    860275
# 740   1945年   岡山県   1564626
# 761   1945年   広島県   1885471
# 782   1945年   山口県   1356491
# 803   1945年   徳島県    835763
# 824   1945年   香川県    863700
# 845   1945年   愛媛県   1361484
# 866   1945年   高知県    775578
# 887   1945年   福岡県   2746855
# 908   1945年   佐賀県    830431
# 929   1945年   長崎県   1318589
# 950   1945年   熊本県   1556490
# 971   1945年   大分県   1124513
# 992   1945年   宮崎県    913687
# 1013  1945年  鹿児島県   1538466
# 1034  1945年   沖縄県         0

# %%
# 可視化のためのデータ加工
## 条件の絞り込み
viz_df = df[df['area'].isin(['香川県','愛媛県','徳島県','高知県'])]

## 軸の名前を明示的に指定して可視化
fig=px.bar(viz_df, x='year', y='value', color='area',barmode='group')
fig.update_layout(
      title='図. 四国4県の人口推移',
      xaxis=dict(title='調査年'),
      yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c5bc6d7b-f538-40b8-b4ea-fe19600c6dea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5bc6d7b-f538-40b8-b4ea-fe19600c6dea")) {                    Plotly.newPlot(                        "c5bc6d7b-f538-40b8-b4ea-fe19600c6dea",                        [{"alignmentgroup":"True","hovertemplate":"area=\u5fb3\u5cf6\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u5fb3\u5cf6\u770c","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u5fb3\u5cf6\u770c","offsetgroup":"\u5fb3\u5cf6\u770c","orientation":"v","showlegend":true,"textposition":"auto","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[670212,689814,716544,728748,718717,835763,878511,878109,847274,815115,791111,805166,825261,834889,831598,832427,824108,809950,785491,755733,719559],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"area=\u9999\u5ddd\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u9999\u5ddd\u770c","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u9999\u5ddd\u770c","offsetgroup":"\u9999\u5ddd\u770c","orientation":"v","showlegend":true,"textposition":"auto","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[677852,700308,732816,748656,730394,863700,946022,943823,918867,900845,907897,961292,999864,1022569,1023412,1027006,1022890,1012400,995842,976263,950244],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"area=\u611b\u5a9b\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u611b\u5a9b\u770c","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u611b\u5a9b\u770c","offsetgroup":"\u611b\u5a9b\u770c","orientation":"v","showlegend":true,"textposition":"auto","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[1046720,1096366,1142122,1164898,1178705,1361484,1521878,1540628,1500687,1446384,1418124,1465215,1506637,1529983,1515025,1506700,1493092,1467815,1431493,1385262,1334841],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"area=\u9ad8\u77e5\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u9ad8\u77e5\u770c","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u9ad8\u77e5\u770c","offsetgroup":"\u9ad8\u77e5\u770c","orientation":"v","showlegend":true,"textposition":"auto","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[670895,687478,718152,714980,709286,775578,873874,882683,854595,812714,786882,808397,831275,839784,825034,816704,813949,796292,764456,728276,691527],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histo ...

# %%
## 軸の名前を明示的に指定して可視化
fig=px.line(viz_df, x='year', y='value', color='area')
fig.update_layout(
    title='図. 四国4県の人口推移',
    xaxis=dict(title='調査年'),
    yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f1aa3a6-80f3-411c-81a4-992cce30e5b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f1aa3a6-80f3-411c-81a4-992cce30e5b3")) {                    Plotly.newPlot(                        "8f1aa3a6-80f3-411c-81a4-992cce30e5b3",                        [{"hovertemplate":"area=\u5fb3\u5cf6\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u5fb3\u5cf6\u770c","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u5fb3\u5cf6\u770c","orientation":"v","showlegend":true,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[670212,689814,716544,728748,718717,835763,878511,878109,847274,815115,791111,805166,825261,834889,831598,832427,824108,809950,785491,755733,719559],"yaxis":"y","type":"scatter"},{"hovertemplate":"area=\u9999\u5ddd\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u9999\u5ddd\u770c","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u9999\u5ddd\u770c","orientation":"v","showlegend":true,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[677852,700308,732816,748656,730394,863700,946022,943823,918867,900845,907897,961292,999864,1022569,1023412,1027006,1022890,1012400,995842,976263,950244],"yaxis":"y","type":"scatter"},{"hovertemplate":"area=\u611b\u5a9b\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u611b\u5a9b\u770c","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u611b\u5a9b\u770c","orientation":"v","showlegend":true,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[1046720,1096366,1142122,1164898,1178705,1361484,1521878,1540628,1500687,1446384,1418124,1465215,1506637,1529983,1515025,1506700,1493092,1467815,1431493,1385262,1334841],"yaxis":"y","type":"scatter"},{"hovertemplate":"area=\u9ad8\u77e5\u770c\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u9ad8\u77e5\u770c","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u9ad8\u77e5\u770c","orientation":"v","showlegend":true,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[670895,687478,718152,714980,709286,775578,873874,882683,854595,812714,786882,808397,831275,839784,825034,816704,813949,796292,764456,728276,691527],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %%
#線形回帰を実施するためのライブラリ
from scipy.stats import linregress

# 可視化のためのデータ加工
viz_df = df[df['area']=='全国'] #条件の絞り込み

# 折れ線グラフを作成
fig = px.line(viz_df, x='year', y='value')

# 傾向線のために線形回帰を行う
slope, intercept, _, _, _ = linregress(viz_df.index, viz_df['value']) #回帰係数と切片を求める
a = slope #回帰係数
b = intercept #切片
trendline = b + a * viz_df.index #傾向線を定義する

# 傾向線を手動で追加
fig.add_scatter(x=viz_df['year'], y=trendline, mode='lines', name='Trendline')

fig.update_layout(
      title='図. 全国人口の推移（傾向線を添えて）',
      xaxis=dict(title='調査年'),
      yaxis=dict(title='人口'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33a4fd57-ba02-454e-97a1-2f8f3a3f405c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33a4fd57-ba02-454e-97a1-2f8f3a3f405c")) {                    Plotly.newPlot(                        "33a4fd57-ba02-454e-97a1-2f8f3a3f405c",                        [{"hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"xaxis":"x","y":[55963053,59736822,64450005,69254148,73114308,71998104,84114574,90076594,94301623,99209137,104665171,111939643,117060396,121048923,123611167,125570246,126925843,127767994,128057352,127094745,126146099],"yaxis":"y","type":"scatter"},{"mode":"lines","name":"Trendline","x":["1920\u5e74","1925\u5e74","1930\u5e74","1935\u5e74","1940\u5e74","1945\u5e74","1950\u5e74","1955\u5e74","1960\u5e74","1965\u5e74","1970\u5e74","1975\u5e74","1980\u5e74","1985\u5e74","1990\u5e74","1995\u5e74","2000\u5e74","2005\u5e74","2010\u5e74","2015\u5e74","2020\u5e74"],"y":[59497831.294372305,63558076.4839827,67618321.67359309,71678566.86320347,75738812.05281386,79799057.24242425,83859302.43203464,87919547.62164503,91979792.81125543,96040038.00086582,100100283.1904762,104160528.38008659,108220773.56969698,112281018.75930735,116341263.94891775,120401509.13852814,124461754.32813853,128521999.51774892,132582244.70735931,136642489.89696968,140702735.0865801],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...

# %%
# #行の表示数の上限を撤廃
# pd.set_option('display.max_rows', None)
# #列の表示数の上限を撤廃
# pd.set_option('display.max_columns', None)

# %%
# fig = px.scatter(viz_df,x='year',y='value',trendline='ols',trendline_color_override='darkblue')
# fig.update_layout(
#       title='図. 全国人口の推移（傾向線を添えて）',
#       xaxis=dict(title='調査年'),
#       yaxis=dict(title='人口'))
